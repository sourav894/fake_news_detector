# %%
# Import the libraries 
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
import re 
import string

# %% [markdown]
# # Load the Datasets

# %%
# Load the datasets 
data_fake = pd.read_csv(r"C:\Users\mahan\Downloads\Fake.csv")
data_true = pd.read_csv(r"C:\Users\mahan\Downloads\True.csv")

# %%
data_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
data_true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
data_fake.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23481 entries, 0 to 23480
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    23481 non-null  object
#  1   text     23481 non-null  object
#  2   subject  23481 non-null  object
#  3   date     23481 non-null  object
# dtypes: object(4)
# memory usage: 733.9+ KB

# %%
data_fake.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23481 entries, 0 to 23480
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    23481 non-null  object
#  1   text     23481 non-null  object
#  2   subject  23481 non-null  object
#  3   date     23481 non-null  object
# dtypes: object(4)
# memory usage: 733.9+ KB

# %%
#get the shape of the datasets 
data_fake.shape, data_true.shape
# Out:
# ((23481, 4), (21417, 4))

# %%
# Add a 'class' column(target column) to the each dataset
data_fake['class'] = 0 
data_true['class'] = 1

# %%
data_fake.head(10)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
# 5   Racist Alabama Cops Brutalize Black Boy While...
# 6   Fresh Off The Golf Course, Trump Lashes Out A...
# 7   Trump Said Some INSANELY Racist Stuff Inside ...
# 8   Former CIA Director Slams Trump Over UN Bully...
# 9   WATCH: Brand-New Pro-Trump Ad Features So Muc...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
# ...

# %%
data_true.head(10)
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
# 5  White House, Congress prepare for talks on spe...
# 6  Trump says Russia probe will be fair, but time...
# 7  Factbox: Trump on Twitter (Dec 29) - Approval ...
# 8         Trump on Twitter (Dec 28) - Global Warming
# 9  Alabama official to certify Senator-elect Jone...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# ...

# %%
data_fake.shape, data_true.shape
# Out:
# ((23481, 5), (21417, 5))

# %%
# Merge the datasets the datasets 
data_merge =  pd.concat([data_fake, data_true])
data_merge.head(10)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
# 5   Racist Alabama Cops Brutalize Black Boy While...
# 6   Fresh Off The Golf Course, Trump Lashes Out A...
# 7   Trump Said Some INSANELY Racist Stuff Inside ...
# 8   Former CIA Director Slams Trump Over UN Bully...
# 9   WATCH: Brand-New Pro-Trump Ad Features So Muc...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
# ...

# %%
data_merge.tail(10)
# Out:
#                                                    title  \
# 21407  Mata Pires, owner of embattled Brazil builder ...
# 21408  U.S., North Korea clash at U.N. forum over nuc...
# 21409  U.S., North Korea clash at U.N. arms forum on ...
# 21410  Headless torso could belong to submarine journ...
# 21411  North Korea shipments to Syria chemical arms a...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21407  SAO PAULO (Reuters) - Cesar Mata Pires, the ow...  worldnews
# 21408  GENEVA (Reuters) - North Korea and the United ...  worldnews
# 21409  GENEVA (Reuters) - North Korea and the United ...  worldnews
# ...

# %%
data_merge.shape
# Out:
# (44898, 5)

# %%
# see all the columns 
data_merge.columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'class'], dtype='object')

# %%
#check the null values 
data_merge.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# class      0
# dtype: int64

# %%
#Check how many fake and real news items you have:
data_merge['class'].value_counts()
# Out:
# class
# 0    23481
# 1    21417
# Name: count, dtype: int64

# %%
# Visualize
import seaborn as sns

plt.figure(figsize=(12, 8))
plt.title('Fake News Vs Real News')

palette = {'0': 'red', '1': 'green'}
sns.countplot(x='class', data=data_merge, palette = palette)
plt.show()
# Out:
# C:\Users\mahan\AppData\Local\Temp\ipykernel_27756\72904224.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='class', data=data_merge, palette = palette)

# %%
df= data_merge.drop(['subject', 'date'], axis = 1)

# %%
df.head(10)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
# 5   Racist Alabama Cops Brutalize Black Boy While...
# 6   Fresh Off The Golf Course, Trump Lashes Out A...
# 7   Trump Said Some INSANELY Racist Stuff Inside ...
# 8   Former CIA Director Slams Trump Over UN Bully...
# 9   WATCH: Brand-New Pro-Trump Ad Features So Muc...
#
#                                                 text  class
# 0  Donald Trump just couldn t wish all Americans ...      0
# 1  House Intelligence Committee Chairman Devin Nu...      0
# 2  On Friday, it was revealed that former Milwauk...      0
# 3  On Christmas day, Donald Trump announced that ...      0
# 4  Pope Francis used his annual Christmas Day mes...      0
# ...

# %%
df.isnull().sum()
# Out:
# title    0
# text     0
# class    0
# dtype: int64

# %%
df.shape
# Out:
# (44898, 3)

# %%
# Random suffling in the DataFrame and drop the index column 
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# %% [markdown]
# When you do something random in Python (like sample, train_test_split, or shuffle), it gives a different result each time unless you fix the randomness.
#
# random_state = 42 , makes sure that every time you run the code, you get the same shuffled output.

# %% [markdown]
# 1 => True news
# 0 => fake news

# %%
df.columns
# Out:
# Index(['title', 'text', 'class'], dtype='object')

# %%
df.head()
# Out:
#                                                title  \
# 0  Ben Stein Calls Out 9th Circuit Court: Committ...
# 1  Trump drops Steve Bannon from National Securit...
# 2  Puerto Rico expects U.S. to lift Jones Act shi...
# 3   OOPS: Trump Just Accidentally Confirmed He Le...
# 4  Donald Trump heads for Scotland to reopen a go...
#
#                                                 text  class
# 0  21st Century Wire says Ben Stein, reputable pr...      0
# 1  WASHINGTON (Reuters) - U.S. President Donald T...      1
# 2  (Reuters) - Puerto Rico Governor Ricardo Rosse...      1
# 3  On Monday, Donald Trump once again embarrassed...      0
# 4  GLASGOW, Scotland (Reuters) - Most U.S. presid...      1

# %%
#Measure and compare how long fake vs real articles are.
df['text_length'] = df['text'].apply(len)
sns.histplot(data=df, x='text_length', hue='class', bins=50)
# Out:
# <Axes: xlabel='text_length', ylabel='Count'>

# %%
df.groupby('class')['text_length'].describe()
# Out:
#          count         mean          std  min     25%     50%     75%      max
# class
# 0      23481.0  2547.396235  2532.884399  1.0  1433.0  2166.0  3032.0  51794.0
# 1      21417.0  2383.278517  1684.835730  1.0   914.0  2222.0  3237.0  29781.0

# %% [markdown]
# # Remove outliers

# %%
df = df[df['text_length'] < 20000]

# %%
df.groupby('class')['text_length'].describe()
# Out:
#          count         mean          std  min     25%     50%     75%      max
# class
# 0      23397.0  2453.214472  1918.846332  1.0  1430.0  2161.0  3017.0  19979.0
# 1      21414.0  2380.203372  1664.174571  1.0   914.0  2222.0  3236.0  18633.0

# %%
#Measure and compare how long fake vs real articles are.
df['text_length'] = df['text'].apply(len)
sns.histplot(data=df, x='text_length', hue='class', bins=50)
# Out:
# <Axes: xlabel='text_length', ylabel='Count'>

# %% [markdown]
# # visualise the common words present in fake/real news

# %%
# fake news wordcloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt


plt.figure(figsize=(16,14))
fake_text = " ".join(df[df['class']==0]['text'])
wordcloud = WordCloud(min_font_size = 3, max_words=100, width=1600, height = 800 , background_color='black').generate(fake_text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Fake News Word Cloud", fontsize = 20)
plt.show()

# %%
#True News word cloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt


plt.figure(figsize=(16,14))
true_text = " ".join(df[df['class']==1]['text'])
wordcloud = WordCloud(min_font_size = 3, max_words=100, width=1600, height = 800 , background_color='black').generate(true_text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("True News Word Cloud", fontsize = 20)
plt.show()

# %% [markdown]
# # Create text column(merging all columns)

# %%
df['data_text'] = df['title'] + df['text']

# %%
# #delete the remaining columns
del df['title']
del df['text']
del df['text_length']

# %%
df.head()
# Out:
#    class                                          data_text
# 0      0  Ben Stein Calls Out 9th Circuit Court: Committ...
# 1      1  Trump drops Steve Bannon from National Securit...
# 2      1  Puerto Rico expects U.S. to lift Jones Act shi...
# 3      0   OOPS: Trump Just Accidentally Confirmed He Le...
# 4      1  Donald Trump heads for Scotland to reopen a go...

# %% [markdown]
# # Text Preprocessing

# %%
#Lowercasing
df['lowercase_text'] = df['data_text'].str.lower()

# %%
#Remove Punctuation
import string
exclude = string.punctuation

def remove_punct(text):
  return text.translate(str.maketrans('','',exclude))
#apply the funtion
df['no_punct_text'] = df['lowercase_text'].apply(remove_punct)

# %%
#Word tokenization

from nltk.tokenize import word_tokenize

df['tokens'] = df['no_punct_text'].apply(word_tokenize)

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mahan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mahan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\mahan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\mahan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#Remove Stop Words

stop_words = stopwords.words('english')

# Function to remove stopwords
def remove_stopwords(text):
    no_stopwords = []
    for word in text:
        if word not in stop_words:     
            no_stopwords.append(word)
    return " ".join(no_stopwords)

# Apply the function and store in a new column
df['no_stopwords'] = df['tokens'].apply(remove_stopwords)

# %%
# Lemmatization

import nltk
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()
df['cleand_text'] = df['no_stopwords'].apply(lambda x: " ".join([lemmatizer.lemmatize(word) for word in x.split()]))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\mahan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df.head(10)
# Out:
#    class                                          data_text  \
# 0      0  Ben Stein Calls Out 9th Circuit Court: Committ...
# 1      1  Trump drops Steve Bannon from National Securit...
# 2      1  Puerto Rico expects U.S. to lift Jones Act shi...
# 3      0   OOPS: Trump Just Accidentally Confirmed He Le...
# 4      1  Donald Trump heads for Scotland to reopen a go...
# 5      0   Paul Ryan Responds To Dem’s Sit-In On Gun Con...
# 6      0  AWESOME! DIAMOND AND SILK Rip Into The Press: ...
# 7      0  STAND UP AND CHEER! UKIP Party Leader SLAMS Ge...
# 8      1  North Korea shows no sign it is serious about ...
# 9      1  Trump signals willingness to raise U.S. minimu...
#
#                                       lowercase_text  \
# 0  ben stein calls out 9th circuit court: committ...
# 1  trump drops steve bannon from national securit...
# 2  puerto rico expects u.s. to lift jones act shi...
# 3   oops: trump just accidentally confirmed he le...
# ...

# %% [markdown]
# # define dependent and independent variables

# %%
X = df['cleand_text']  #preprocessed text
y = df['class']       #0 = fake, 1 = real

# %% [markdown]
# # TF-IDF Vectorization

# %%
tfidf = TfidfVectorizer(max_features=5000)
X_tfidf = tfidf.fit_transform(X)

# %% [markdown]
# # split the data

# %%
X_train , X_test, y_train, y_test = train_test_split(X_tfidf,y, test_size = 0.25, random_state = 42)

# %% [markdown]
# # Train the model

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression
model = LR(max_iter = 1000)

model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# # prediction

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9842899223422298

# %%
# Classification Report
print("Classification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      5902
#            1       0.98      0.98      0.98      5301
#
#     accuracy                           0.98     11203
#    macro avg       0.98      0.98      0.98     11203
# weighted avg       0.98      0.98      0.98     11203

# %%
# Confusion Matrix
print("Confusion Matrix:\n")
print(confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
#
# [[5806   96]
#  [  80 5221]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_predictions(y_test, y_pred, cmap='Blues')
plt.title("Confusion Matrix - Logistic Regression")
plt.show()

# %% [markdown]
# # BY SVM classifier

# %%
from sklearn.svm import SVC

svm_model = SVC(kernel = 'linear', C = 1.0, random_state = 42)
svm_model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
#Prediction 
y_pred_svm = svm_model.predict(X_test)

# %%
#Evaluate the Model 
print("Accuracy:", accuracy_score(y_test, y_pred_svm))
print("Classificarion Report:\n", classification_report(y_test, y_pred_svm))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_svm))
# Out:
# Accuracy: 0.9920556993662412
# Classificarion Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5902
#            1       0.99      0.99      0.99      5301
#
#     accuracy                           0.99     11203
#    macro avg       0.99      0.99      0.99     11203
# weighted avg       0.99      0.99      0.99     11203
#
# Confusion Matrix:
#  [[5864   38]
#  [  51 5250]]

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

ConfusionMatrixDisplay.from_predictions(y_test, y_pred_svm, cmap='Greens')
plt.title("Confusion Matrix - SVM")
plt.show()

# %%
from sklearn.decomposition import PCA

# Reduce TF-IDF features to 2 dimensions for plotting
pca = PCA(n_components=2)
X_train_2D = pca.fit_transform(X_train.toarray())
X_test_2D = pca.transform(X_test.toarray())

# %%
svm_pca = SVC(kernel='linear', C=1.0, random_state=42)
svm_pca.fit(X_train_2D, y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define decision boundary plot function
def plot_decision_boundary(model, X, y, title):
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    h = 0.02  # step size

    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.figure(figsize=(10, 6))
    plt.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.coolwarm)
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.coolwarm, edgecolors='k')
    plt.xlabel("PCA Component 1")
    plt.ylabel("PCA Component 2")
    plt.title(title)
    plt.show()

# Call the plot function
plot_decision_boundary(svm_vis, X_train_2D, y_train, "SVM Decision Boundary (PCA Projection)")

# %% [markdown]
# # BY RandomForest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
#Train the model 
rf_model.fit(X_train, y_train)
#predictions
y_pred_rf = rf_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("Accuracy (Random Forest):", accuracy_score(y_test, y_pred_rf))
print("\nClassification Report:\n", classification_report(y_test, y_pred_rf))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_rf))
# Out:
# Accuracy (Random Forest): 0.993573150049094
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5902
#            1       1.00      0.99      0.99      5301
#
#     accuracy                           0.99     11203
#    macro avg       0.99      0.99      0.99     11203
# weighted avg       0.99      0.99      0.99     11203
#
# Confusion Matrix:
#  [[5882   20]
#  [  52 5249]]

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

ConfusionMatrixDisplay.from_predictions(y_test, y_pred_rf, cmap='Purples')
plt.title("Confusion Matrix - Random Forest")
plt.show()

# %% [markdown]
# # Compare All Model Accuracies

# %%
from sklearn.metrics import accuracy_score

# Accuracy scores
acc_logistic = accuracy_score(y_test, y_pred)
acc_svm = accuracy_score(y_test, y_pred_svm)
acc_rf = accuracy_score(y_test, y_pred_rf)

# %%
model_results = {
    'Logistic Regression': acc_logistic,
    'SVM (Linear)': acc_svm,
    'Random Forest': acc_rf
}

for model, acc in model_results.items():
    print(f"{model:20s} → Accuracy: {acc:.4f}")
# Out:
# Logistic Regression  → Accuracy: 0.9843
# SVM (Linear)         → Accuracy: 0.9921
# Random Forest        → Accuracy: 0.9936

# %%
import matplotlib.pyplot as plt

models = list(model_results.keys())
scores = list(model_results.values())

plt.figure(figsize=(10,5))
plt.bar(models, scores, color='skyblue')
plt.ylim(0, 1)
plt.title("Model Accuracy Comparison")
plt.ylabel("Accuracy")
plt.xticks(rotation=15)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# # Save Model

# %%
import joblib

# Save SVM Model 
joblib.dump(svm_model, 'fake_news_model.pkl')

# Save the TF-IDF vectorizer
joblib.dump(tfidf, 'tfidf_vectorizer.pkl')
# Out:
# ['tfidf_vectorizer.pkl']
